# %% [markdown]
# # CSI300 Image Rendering Sensitivity Study
#
# This notebook studies **how different image drawing choices affect prediction and timing performance** for the CSI300 index.
#
# ## Goal
# Keep the **data, labels, train/validation/test split, and 2D CNN architecture fixed**, and only change the **image rendering method**.
# This lets us isolate whether performance differences come from the **image representation itself**.
#
# ## Main comparison directions
# 1. **OHLC-only vs OHLC+MA vs OHLC+MA+Volume**
# 2. **OHLC bars vs candlestick body**
# 3. **Image resolution** (e.g. 48, 64, 96)
# 4. **Volume area ratio** (e.g. bottom 20% vs 30%)
# 5. **Price normalization method** inside each rolling window
#
# ## Output
# For each rendering variant, we will report:
# - validation / test accuracy
# - annual return
# - annual volatility
# - Sharpe ratio
# - max drawdown
# - timing strategy NAV vs HS300 buy-and-hold

# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, BatchNormalization,
    GlobalAveragePooling2D, Dense, Dropout
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

from sklearn.metrics import accuracy_score, classification_report

# %%
# ============================================================
# 1. Imports and random seed
# ============================================================
import os
import random
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, BatchNormalization,
    GlobalAveragePooling2D, Dense, Dropout
)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

SEED = 42
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.keras.utils.set_random_seed(SEED)

print("TensorFlow version:", tf.__version__)
print("Random seed fixed:", SEED)
# Out:
# TensorFlow version: 2.21.0
# Random seed fixed: 42

# %% [markdown]
# ## Data assumption
#
# This notebook assumes you already have:
# - merged daily file: `CSI300_merged_2005_2026.csv`
# - rolling-window file with **OHLC + volume + ma20** features
#
# If you do not yet have the rolling-window file with volume and MA, the next cell will build it from the merged CSV.

# %%
# ============================================================
# 2. Build rolling-window dataset with OHLC + volume + ma20
# ============================================================
folder_path = "."
price_file = os.path.join(folder_path, "CSI300_merged_2005_2026.csv")
npz_file = os.path.join(folder_path, "CSI300_window20_label5d_ohlc_volume_ma.npz")

WINDOW = 20
HORIZON = 5

if not os.path.exists(npz_file):
    df = pd.read_csv(price_file)
    df["date"] = pd.to_datetime(df["date"])
    df = df.sort_values("date").reset_index(drop=True)

    # create ma20
    df["ma20"] = df["close"].rolling(20).mean()

    # keep needed columns
    df = df[["date", "open", "high", "low", "close", "volume", "ma20"]].copy()

    # label: future 5-day return > 0
    df["future_5d_ret"] = df["close"].shift(-HORIZON) / df["close"] - 1
    df["label_5d"] = (df["future_5d_ret"] > 0).astype(int)

    # drop rows where ma20 is not available
    df = df.dropna(subset=["ma20"]).reset_index(drop=True)

    feature_cols = ["open", "high", "low", "close", "volume", "ma20"]

    X, y, dates = [], [], []
    for i in range(WINDOW - 1, len(df) - HORIZON):
        window_data = df.loc[i-WINDOW+1:i, feature_cols].values
        label = df.loc[i, "label_5d"]
        sample_date = df.loc[i, "date"]
        X.append(window_data)
        y.append(label)
        dates.append(sample_date)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.int64)
    dates = np.array(dates).astype(str)

    np.savez(npz_file, X=X, y=y, dates=dates)
    print("Saved:", npz_file)
else:
    print("Existing dataset found:", npz_file)
# Out:
# Existing dataset found: /Users/daijinyang/Desktop/HS300/CSI300_window20_label5d_ohlc_volume_ma.npz

# %%
# ============================================================
# 3. Load rolling-window dataset
# ============================================================
data = np.load(npz_file, allow_pickle=True)
X = data["X"]      # shape: (n_samples, 20, 6)
y = data["y"]
dates = data["dates"]

print("X shape:", X.shape)
print("y shape:", y.shape)
print("dates shape:", dates.shape)

# time-based split
n = len(X)
train_end = int(n * 0.6)
valid_end = int(n * 0.8)

X_train = X[:train_end]
y_train = y[:train_end]

X_valid = X[train_end:valid_end]
y_valid = y[train_end:valid_end]

X_test = X[valid_end:]
y_test = y[valid_end:]

dates_train = dates[:train_end]
dates_valid = dates[train_end:valid_end]
dates_test = dates[valid_end:]

print("Train:", X_train.shape, y_train.shape)
print("Valid:", X_valid.shape, y_valid.shape)
print("Test :", X_test.shape, y_test.shape)
print("Train period:", dates_train[0], "to", dates_train[-1])
print("Valid period:", dates_valid[0], "to", dates_valid[-1])
print("Test  period:", dates_test[0], "to", dates_test[-1])
# Out:
# X shape: (5114, 20, 6)
# y shape: (5114,)
# dates shape: (5114,)
# Train: (3068, 20, 6) (3068,)
# Valid: (1023, 20, 6) (1023,)
# Test : (1023, 20, 6) (1023,)
# Train period: 2005-03-08 00:00:00 to 2017-10-17 00:00:00
# Valid period: 2017-10-18 00:00:00 to 2021-12-28 00:00:00
# Test  period: 2021-12-29 00:00:00 to 2026-03-24 00:00:00

# %% [markdown]
# ## Backtest helper functions
#
# The backtest in this notebook now follows **Scheme A**:
#
# - the model generates a raw signal on date `t`,
# - if the strategy enters, it holds the CSI300 for the next **5 trading days**,
# - all signals that arrive during those 5 holding days are ignored.

# %%
# ============================================================
# 4. Backtest and performance functions
# ============================================================
def annualized_return(ret_series, periods_per_year=244):
    ret_series = pd.Series(ret_series).dropna()
    if len(ret_series) == 0:
        return np.nan
    nav = (1 + ret_series).prod()
    return nav ** (periods_per_year / len(ret_series)) - 1

def annualized_volatility(ret_series, periods_per_year=244):
    ret_series = pd.Series(ret_series).dropna()
    if len(ret_series) == 0:
        return np.nan
    return ret_series.std() * np.sqrt(periods_per_year)

def sharpe_ratio(ret_series, periods_per_year=244, rf=0):
    ann_ret = annualized_return(ret_series, periods_per_year)
    ann_vol = annualized_volatility(ret_series, periods_per_year)
    if ann_vol == 0 or pd.isna(ann_vol):
        return np.nan
    return (ann_ret - rf) / ann_vol

def max_drawdown(nav_series):
    nav_series = pd.Series(nav_series).dropna()
    if len(nav_series) == 0:
        return np.nan
    rolling_max = nav_series.cummax()
    drawdown = nav_series / rolling_max - 1
    return drawdown.min()

def backtest_from_prob(dates_test, y_test_prob, threshold=0.5,
                       price_file=price_file, horizon=5):
    """
    Scheme A backtest used in this notebook:
    - the model generates a raw signal on sample date t,
    - if the strategy enters, it holds the index for the next 5 trading days,
    - all new signals are ignored during those 5 holding days.
    """
    signal_df = pd.DataFrame({
        "date": pd.to_datetime(dates_test),
        "y_prob": y_test_prob
    }).sort_values("date").reset_index(drop=True)
    signal_df["raw_signal"] = (signal_df["y_prob"] > threshold).astype(int)

    px = pd.read_csv(price_file)
    px["date"] = pd.to_datetime(px["date"])
    px = px.sort_values("date").reset_index(drop=True)
    px["ret_1d"] = px["close"].pct_change()

    date_to_idx = {pd.Timestamp(d): i for i, d in enumerate(px["date"])}
    positions = np.zeros(len(px), dtype=int)

    used_signals = []
    ignored_signals = []
    active_until_idx = -1

    for _, row in signal_df.iterrows():
        signal_date = pd.Timestamp(row["date"])
        raw_signal = int(row["raw_signal"])
        idx = date_to_idx.get(signal_date)

        if idx is None or idx + horizon >= len(px):
            used_signals.append(0)
            ignored_signals.append(0)
            continue

        if idx < active_until_idx:
            used_signals.append(0)
            ignored_signals.append(1)
            continue

        if raw_signal == 1:
            positions[idx + 1: idx + horizon + 1] = 1
            active_until_idx = idx + horizon
            used_signals.append(1)
            ignored_signals.append(0)
        else:
            used_signals.append(0)
            ignored_signals.append(0)

    signal_df["used_signal"] = used_signals
    signal_df["ignored_signal"] = ignored_signals

    valid_signal_dates = signal_df["date"].map(date_to_idx).dropna().astype(int)
    if len(valid_signal_dates) == 0:
        raise ValueError("No test dates were matched to the price file.")

    start_idx = int(valid_signal_dates.iloc[0]) + 1
    end_idx = min(int(valid_signal_dates.iloc[-1]) + horizon, len(px) - 1)

    result_df = px.loc[start_idx:end_idx, ["date", "ret_1d"]].copy().reset_index(drop=True)
    result_df["signal"] = positions[start_idx:end_idx + 1]
    result_df["strategy_ret"] = result_df["signal"] * result_df["ret_1d"]
    result_df["buy_hold_ret"] = result_df["ret_1d"]

    result_df["strategy_nav"] = (1 + result_df["strategy_ret"]).cumprod()
    result_df["buy_hold_nav"] = (1 + result_df["buy_hold_ret"]).cumprod()

    summary = {
        "Annual Return": annualized_return(result_df["strategy_ret"]),
        "Annual Vol": annualized_volatility(result_df["strategy_ret"]),
        "Sharpe": sharpe_ratio(result_df["strategy_ret"]),
        "Max Drawdown": max_drawdown(result_df["strategy_nav"]),
        "BuyHold Annual Return": annualized_return(result_df["buy_hold_ret"]),
        "BuyHold Annual Vol": annualized_volatility(result_df["buy_hold_ret"]),
        "BuyHold Sharpe": sharpe_ratio(result_df["buy_hold_ret"]),
        "BuyHold Max Drawdown": max_drawdown(result_df["buy_hold_nav"]),
        "Average Exposure": result_df["signal"].mean(),
        "Used Signal Ratio": signal_df["used_signal"].mean(),
        "Ignored Signal Ratio": signal_df["ignored_signal"].mean()
    }
    return result_df, summary, signal_df

def plot_strategy_vs_hs300_visible(result_df, model_name):
    plt.figure(figsize=(12, 6))
    plt.plot(result_df["date"], result_df["buy_hold_nav"],
             label="HS300 Buy-and-Hold", linewidth=3, alpha=0.85, zorder=1)
    plt.plot(result_df["date"], result_df["strategy_nav"],
             label=f"{model_name} Timing Strategy",
             linewidth=1.8, linestyle="--", marker="o", markersize=2,
             markevery=max(1, len(result_df)//40), zorder=3)
    plt.title(f"{model_name} vs HS300 Buy-and-Hold (5-Day Silent Holding Rule)")
    plt.xlabel("Date")
    plt.ylabel("Net Asset Value")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 4))
    plt.plot(result_df["date"],
             result_df["strategy_nav"] - result_df["buy_hold_nav"],
             linewidth=1.5)
    plt.axhline(0, color="black", linestyle="--")
    plt.title(f"{model_name}: Strategy NAV - HS300 NAV")
    plt.xlabel("Date")
    plt.ylabel("NAV Difference")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Rendering variants
#
# Below we define several image-drawing choices.
#
# ### Planned variants
# - **V1_OHLC**: OHLC bars only
# - **V2_OHLC_MA**: OHLC bars + MA20 line
# - **V3_OHLC_MA_VOL**: OHLC bars + MA20 + volume bars
# - **V4_CANDLE_MA_VOL**: candlestick body + wick + MA20 + volume
# - **V5_HIGHRES_OHLC_MA_VOL**: same as V3 but higher image resolution
# - **V6_VOL30_OHLC_MA_VOL**: same as V3 but allocate more image space to volume

# %%
# ============================================================
# 5. Image rendering functions
# ============================================================
def _scale_price_to_y(price, max_price, min_price, price_h):
    if max_price == min_price:
        max_price += 1e-6
    y = int(round((max_price - price) / (max_price - min_price) * (price_h - 1)))
    return int(np.clip(y, 0, price_h - 1))

def render_ohlc_image(window, height=64, include_ma=False, include_volume=False,
                      volume_ratio=0.2):
    '''
    Render OHLC image using the EXACT same drawing logic as the stronger 2D CNN notebook
    whenever MA / volume are included:
    - OHLC wick/ticks in white (255)
    - MA drawn as a single point at x0+1 with grayscale 180 (NOT a connected line)
    - volume bars drawn with grayscale 120
    '''
    n_days = window.shape[0]
    width = n_days * 3
    img = np.zeros((height, width), dtype=np.uint8)

    price_h = int(height * (1 - volume_ratio)) if include_volume else height
    vol_h = height - price_h if include_volume else 0

    open_ = window[:, 0]
    high_ = window[:, 1]
    low_  = window[:, 2]
    close_= window[:, 3]
    vol_  = window[:, 4]
    ma20_ = window[:, 5]

    max_price = np.max(high_)
    min_price = np.min(low_)
    max_vol = np.max(vol_) if np.max(vol_) > 0 else 1e-6

    for i in range(n_days):
        x0 = i * 3
        o, h, l, c = open_[i], high_[i], low_[i], close_[i]

        y_open  = _scale_price_to_y(o, max_price, min_price, price_h)
        y_high  = _scale_price_to_y(h, max_price, min_price, price_h)
        y_low   = _scale_price_to_y(l, max_price, min_price, price_h)
        y_close = _scale_price_to_y(c, max_price, min_price, price_h)

        # Stronger notebook OHLC rendering
        img[min(y_high, y_low):max(y_high, y_low)+1, x0+1] = 255
        img[y_open, x0] = 255
        img[y_close, x0+2] = 255

        if include_ma:
            y_ma = _scale_price_to_y(ma20_[i], max_price, min_price, price_h)
            # EXACT stronger notebook style: one MA point, not a connected line
            img[y_ma, x0+1] = 180

        if include_volume and vol_h > 0:
            # EXACT stronger notebook volume style
            bar_h = int(round(vol_[i] / max_vol * max(1, vol_h - 1)))
            if bar_h > 0:
                img[price_h + (vol_h - bar_h):height, x0:x0+3] = 120

    return img

def render_candlestick_image(window, height=64, include_ma=True, include_volume=True,
                             volume_ratio=0.2):
    '''
    Candlestick body + wick + MA20 + volume.
    For consistency with the stronger notebook alignment request:
    - MA is drawn as a single point (not a connected line)
    - volume bars use grayscale 120
    '''
    n_days = window.shape[0]
    width = n_days * 3
    img = np.zeros((height, width), dtype=np.uint8)

    price_h = int(height * (1 - volume_ratio)) if include_volume else height
    vol_h = height - price_h if include_volume else 0

    open_ = window[:, 0]
    high_ = window[:, 1]
    low_  = window[:, 2]
    close_= window[:, 3]
    vol_  = window[:, 4]
    ma20_ = window[:, 5]

    max_price = np.max(high_)
    min_price = np.min(low_)
    max_vol = np.max(vol_) if np.max(vol_) > 0 else 1e-6

    for i in range(n_days):
        x0 = i * 3
        o, h, l, c = open_[i], high_[i], low_[i], close_[i]

        y_open  = _scale_price_to_y(o, max_price, min_price, price_h)
        y_high  = _scale_price_to_y(h, max_price, min_price, price_h)
        y_low   = _scale_price_to_y(l, max_price, min_price, price_h)
        y_close = _scale_price_to_y(c, max_price, min_price, price_h)

        # Wick
        img[min(y_high, y_low):max(y_high, y_low)+1, x0+1] = 255

        # Body
        top = min(y_open, y_close)
        bottom = max(y_open, y_close)
        body_intensity = 220 if c >= o else 140
        img[top:bottom+1, x0:x0+3] = body_intensity

        if include_ma:
            y_ma = _scale_price_to_y(ma20_[i], max_price, min_price, price_h)
            img[y_ma, x0+1] = 180

        if include_volume and vol_h > 0:
            bar_h = int(round(vol_[i] / max_vol * max(1, vol_h - 1)))
            if bar_h > 0:
                img[price_h + (vol_h - bar_h):height, x0:x0+3] = 120

    return img

# %%
# ============================================================
# 6. Build image dataset for each variant
# ============================================================
def build_image_dataset(X, variant_name):
    if variant_name == "V1_OHLC":
        imgs = [render_ohlc_image(x, height=64, include_ma=False, include_volume=False)
                for x in X]
    elif variant_name == "V2_OHLC_MA":
        imgs = [render_ohlc_image(x, height=64, include_ma=True, include_volume=False)
                for x in X]
    elif variant_name == "V3_OHLC_MA_VOL":
        imgs = [render_ohlc_image(x, height=64, include_ma=True, include_volume=True, volume_ratio=0.2)
                for x in X]
    elif variant_name == "V4_CANDLE_MA_VOL":
        imgs = [render_candlestick_image(x, height=64, include_ma=True, include_volume=True, volume_ratio=0.2)
                for x in X]
    elif variant_name == "V5_HIGHRES_OHLC_MA_VOL":
        imgs = [render_ohlc_image(x, height=96, include_ma=True, include_volume=True, volume_ratio=0.2)
                for x in X]
    elif variant_name == "V6_VOL30_OHLC_MA_VOL":
        imgs = [render_ohlc_image(x, height=64, include_ma=True, include_volume=True, volume_ratio=0.3)
                for x in X]
    else:
        raise ValueError(f"Unknown variant: {variant_name}")

    imgs = np.array(imgs, dtype=np.float32) / 255.0
    imgs = imgs[..., np.newaxis]
    return imgs

# %% [markdown]
# ## Preview sample images for each rendering variant

# %%
# ============================================================
# 7. Visual check of different rendering methods
# ============================================================
variants = [
    "V1_OHLC",
    "V2_OHLC_MA",
    "V3_OHLC_MA_VOL",
    "V4_CANDLE_MA_VOL",
    "V5_HIGHRES_OHLC_MA_VOL",
    "V6_VOL30_OHLC_MA_VOL"
]

sample_idx = 100

fig, axes = plt.subplots(len(variants), 1, figsize=(10, 2.5 * len(variants)))
for ax, v in zip(axes, variants):
    img = build_image_dataset(X_train[sample_idx:sample_idx+1], v)[0].squeeze()
    ax.imshow(img, cmap="gray", aspect="auto")
    ax.set_title(f"{v} | label={y_train[sample_idx]}")
    ax.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Shared 2D CNN
#
# To isolate the effect of image rendering, we keep the CNN architecture and training setup aligned with the **Stronger 2D CNN** notebook.

# %%
# ============================================================
# 8. Shared 2D CNN architecture (identical to Stronger 2D CNN)
# ============================================================
def make_2dcnn(input_shape, learning_rate=5e-4):
    model = Sequential([
        Input(shape=input_shape),

        Conv2D(32, (3, 3), activation="relu", padding="same"),
        BatchNormalization(),
        Conv2D(32, (3, 3), activation="relu", padding="same"),
        MaxPooling2D((2, 2)),
        Dropout(0.15),

        Conv2D(64, (3, 3), activation="relu", padding="same"),
        BatchNormalization(),
        Conv2D(64, (3, 3), activation="relu", padding="same"),
        MaxPooling2D((2, 2)),
        Dropout(0.20),

        Conv2D(128, (3, 3), activation="relu", padding="same"),
        BatchNormalization(),
        Conv2D(128, (3, 3), activation="relu", padding="same"),
        MaxPooling2D((2, 2)),
        Dropout(0.25),

        Conv2D(256, (3, 3), activation="relu", padding="same"),
        BatchNormalization(),
        GlobalAveragePooling2D(),

        Dense(128, activation="relu"),
        Dropout(0.30),
        Dense(64, activation="relu"),
        Dropout(0.20),

        Dense(1, activation="sigmoid")
    ])
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %% [markdown]
# ## Single-variant training function

# %%
# ============================================================
# 9. Train + evaluate one rendering variant
# ============================================================
def train_variant(variant_name, threshold=0.5, epochs=100, batch_size=32, verbose=1):
    print("=" * 80)
    print("Training variant:", variant_name)

    # Fix the random seed so that the training setup stays aligned with the Stronger 2D CNN notebook.
    import random
    SEED = 42
    os.environ["PYTHONHASHSEED"] = str(SEED)
    random.seed(SEED)
    np.random.seed(SEED)
    tf.random.set_seed(SEED)
    tf.keras.utils.set_random_seed(SEED)

    X_train_img = build_image_dataset(X_train, variant_name)
    X_valid_img = build_image_dataset(X_valid, variant_name)
    X_test_img  = build_image_dataset(X_test,  variant_name)

    model = make_2dcnn(X_train_img.shape[1:])

    checkpoint_path = os.path.join(folder_path, f"best_{variant_name}_stronger.keras")

    early_stop = EarlyStopping(
        monitor="val_loss",
        patience=15,
        restore_best_weights=True,
        verbose=1
    )

    reduce_lr = ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=6,
        min_lr=1e-6,
        verbose=1
    )

    checkpoint = ModelCheckpoint(
        checkpoint_path,
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    )

    history = model.fit(
        X_train_img, y_train,
        validation_data=(X_valid_img, y_valid),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stop, reduce_lr, checkpoint],
        verbose=verbose
    )

    y_valid_prob = model.predict(X_valid_img, verbose=0).ravel()
    y_valid_pred = (y_valid_prob > 0.5).astype(int)

    y_test_prob = model.predict(X_test_img, verbose=0).ravel()
    y_test_pred = (y_test_prob > 0.5).astype(int)

    bt_df, bt_summary, signal_df = backtest_from_prob(dates_test, y_test_prob, threshold=threshold)

    row = {
        "Variant": variant_name,
        "Validation Accuracy": accuracy_score(y_valid, y_valid_pred),
        "Test Accuracy": accuracy_score(y_test, y_test_pred),
        "Annual Return": bt_summary["Annual Return"],
        "Annual Vol": bt_summary["Annual Vol"],
        "Sharpe": bt_summary["Sharpe"],
        "Max Drawdown": bt_summary["Max Drawdown"],
        "Average Exposure": bt_df["signal"].mean()
    }

    return model, history, bt_df, row

# %% [markdown]
# ## Run all rendering experiments

# %%
# ============================================================
# 10. Run all variants
# ============================================================
results = []
backtests = {}
histories = {}
models = {}

for v in variants:
    model, history, bt_df, row = train_variant(
        v,
        threshold=0.5,
        epochs=100,
        batch_size=32,
        verbose=1
    )
    models[v] = model
    histories[v] = history
    backtests[v] = bt_df
    results.append(row)

summary_df = pd.DataFrame(results).sort_values(
    by=["Sharpe", "Annual Return", "Test Accuracy"],
    ascending=False
).reset_index(drop=True)

summary_df
# Out:
# ================================================================================
# Training variant: V1_OHLC
# Epoch 1/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5292 - loss: 0.6897
# Epoch 1: val_loss improved from None to 0.86028, saving model to /Users/daijinyang/Desktop/HS300/best_V1_OHLC_stronger.keras
#
# Epoch 1: finished saving model to /Users/daijinyang/Desktop/HS300/best_V1_OHLC_stronger.keras
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 14s 127ms/step - accuracy: 0.5391 - loss: 0.6886 - val_accuracy: 0.5474 - val_loss: 0.8603 - learning_rate: 5.0000e-04
# Epoch 2/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5432 - loss: 0.6839
# Epoch 2: val_loss improved from 0.86028 to 0.78963, saving model to /Users/daijinyang/Desktop/HS300/best_V1_OHLC_stronger.keras
#
# Epoch 2: finished saving model to /Users/daijinyang/Desktop/HS300/best_V1_OHLC_stronger.keras
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 13s 133ms/step - accuracy: 0.5398 - loss: 0.6877 - val_accuracy: 0.5474 - val_loss: 0.7896 - learning_rate: 5.0000e-04
# Epoch 3/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.5628 - loss: 0.6776
# Epoch 3: val_loss did not improve from 0.78963
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 13s 138ms/step - accuracy: 0.5593 - loss: 0.6812 - val_accuracy: 0.5474 - val_loss: 0.8155 - learning_rate: 5.0000e-04
# Epoch 4/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5677 - loss: 0.6728
# Epoch 4: val_loss did not improve from 0.78963
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 13s 136ms/step - accuracy: 0.5678 - loss: 0.6759 - val_accuracy: 0.5474 - val_loss: 1.0625 - learning_rate: 5.0000e-04
# Epoch 5/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5732 - loss: 0.6726
# Epoch 5: val_loss did not improve from 0.78963
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 13s 139ms/step - accuracy: 0.5851 - loss: 0.6743 - val_accuracy: 0.5474 - val_loss: 1.0547 - learning_rate: 5.0000e-04
# Epoch 6/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.5896 - loss: 0.6693
# Epoch 6: val_loss did not improve from 0.78963
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 14s 142ms/step - accuracy: 0.5962 - loss: 0.6702 - val_accuracy: 0.5474 - val_loss: 1.0405 - learning_rate: 5.0000e-04
# Epoch 7/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.6005 - loss: 0.6635
# Epoch 7: val_loss did not improve from 0.78963
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 14s 150ms/step - accuracy: 0.6007 - loss: 0.6617 - val_accuracy: 0.5474 - val_loss: 1.3389 - learning_rate: 5.0000e-04
# Epoch 8/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.6057 - loss: 0.6493
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 8: val_loss did not improve from 0.78963
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 162ms/step - accuracy: 0.6108 - loss: 0.6469 - val_accuracy: 0.5474 - val_loss: 1.4367 - learning_rate: 5.0000e-04
# Epoch 9/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.6466 - loss: 0.6288
# Epoch 9: val_loss did not improve from 0.78963
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - accuracy: 0.6581 - loss: 0.6159 - val_accuracy: 0.5474 - val_loss: 2.3968 - learning_rate: 2.5000e-04
# Epoch 10/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.6727 - loss: 0.5945
# Epoch 10: val_loss did not improve from 0.78963
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 188ms/step - accuracy: 0.6789 - loss: 0.5946 - val_accuracy: 0.5474 - val_loss: 2.2207 - learning_rate: 2.5000e-04
# Epoch 11/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.6959 - loss: 0.5805
# Epoch 11: val_loss did not improve from 0.78963
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - accuracy: 0.7018 - loss: 0.5760 - val_accuracy: 0.5474 - val_loss: 1.5485 - learning_rate: 2.5000e-04
# Epoch 12/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.6946 - loss: 0.5585
# Epoch 12: val_loss did not improve from 0.78963
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 193ms/step - accuracy: 0.7119 - loss: 0.5548 - val_accuracy: 0.5464 - val_loss: 1.6379 - learning_rate: 2.5000e-04
# Epoch 13/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7425 - loss: 0.5266
# Epoch 13: val_loss did not improve from 0.78963
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 19s 193ms/step - accuracy: 0.7454 - loss: 0.5224 - val_accuracy: 0.5474 - val_loss: 1.8942 - learning_rate: 2.5000e-04
# Epoch 14/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.7619 - loss: 0.5107
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 14: val_loss did not improve from 0.78963
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 188ms/step - accuracy: 0.7741 - loss: 0.4942 - val_accuracy: 0.5474 - val_loss: 2.1392 - learning_rate: 2.5000e-04
# Epoch 15/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7743 - loss: 0.4739
# Epoch 15: val_loss did not improve from 0.78963
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 187ms/step - accuracy: 0.7774 - loss: 0.4606 - val_accuracy: 0.5474 - val_loss: 3.0785 - learning_rate: 1.2500e-04
# Epoch 16/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7938 - loss: 0.4453
# Epoch 16: val_loss did not improve from 0.78963
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 181ms/step - accuracy: 0.7963 - loss: 0.4398 - val_accuracy: 0.5474 - val_loss: 2.4145 - learning_rate: 1.2500e-04
# Epoch 17/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8005 - loss: 0.4363
# Epoch 17: val_loss did not improve from 0.78963
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 176ms/step - accuracy: 0.8077 - loss: 0.4232 - val_accuracy: 0.5474 - val_loss: 2.6662 - learning_rate: 1.2500e-04
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 2.
# ================================================================================
# Training variant: V2_OHLC_MA
# Epoch 1/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.5404 - loss: 0.6901
# Epoch 1: val_loss improved from None to 0.81477, saving model to /Users/daijinyang/Desktop/HS300/best_V2_OHLC_MA_stronger.keras
#
# Epoch 1: finished saving model to /Users/daijinyang/Desktop/HS300/best_V2_OHLC_MA_stronger.keras
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 20s 189ms/step - accuracy: 0.5469 - loss: 0.6888 - val_accuracy: 0.5474 - val_loss: 0.8148 - learning_rate: 5.0000e-04
# Epoch 2/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.5730 - loss: 0.6745
# Epoch 2: val_loss improved from 0.81477 to 0.70795, saving model to /Users/daijinyang/Desktop/HS300/best_V2_OHLC_MA_stronger.keras
#
# Epoch 2: finished saving model to /Users/daijinyang/Desktop/HS300/best_V2_OHLC_MA_stronger.keras
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 189ms/step - accuracy: 0.5642 - loss: 0.6811 - val_accuracy: 0.5474 - val_loss: 0.7080 - learning_rate: 5.0000e-04
# Epoch 3/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.5591 - loss: 0.6752
# Epoch 3: val_loss did not improve from 0.70795
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 176ms/step - accuracy: 0.5698 - loss: 0.6773 - val_accuracy: 0.4526 - val_loss: 0.7278 - learning_rate: 5.0000e-04
# Epoch 4/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.5773 - loss: 0.6712
# Epoch 4: val_loss improved from 0.70795 to 0.69463, saving model to /Users/daijinyang/Desktop/HS300/best_V2_OHLC_MA_stronger.keras
#
# Epoch 4: finished saving model to /Users/daijinyang/Desktop/HS300/best_V2_OHLC_MA_stronger.keras
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 176ms/step - accuracy: 0.5740 - loss: 0.6748 - val_accuracy: 0.4848 - val_loss: 0.6946 - learning_rate: 5.0000e-04
# Epoch 5/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.5828 - loss: 0.6699
# Epoch 5: val_loss did not improve from 0.69463
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 173ms/step - accuracy: 0.5867 - loss: 0.6705 - val_accuracy: 0.4594 - val_loss: 0.7103 - learning_rate: 5.0000e-04
# Epoch 6/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.6061 - loss: 0.6620
# Epoch 6: val_loss did not improve from 0.69463
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 172ms/step - accuracy: 0.5916 - loss: 0.6669 - val_accuracy: 0.4790 - val_loss: 0.8359 - learning_rate: 5.0000e-04
# Epoch 7/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.6013 - loss: 0.6570
# Epoch 7: val_loss did not improve from 0.69463
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 172ms/step - accuracy: 0.6053 - loss: 0.6583 - val_accuracy: 0.4555 - val_loss: 0.8267 - learning_rate: 5.0000e-04
# Epoch 8/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.6073 - loss: 0.6560
# Epoch 8: val_loss did not improve from 0.69463
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 183ms/step - accuracy: 0.6154 - loss: 0.6560 - val_accuracy: 0.4487 - val_loss: 1.2479 - learning_rate: 5.0000e-04
# Epoch 9/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.6386 - loss: 0.6370
# Epoch 9: val_loss did not improve from 0.69463
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - accuracy: 0.6330 - loss: 0.6375 - val_accuracy: 0.4673 - val_loss: 0.9690 - learning_rate: 5.0000e-04
# Epoch 10/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.6632 - loss: 0.6261
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 10: val_loss did not improve from 0.69463
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 173ms/step - accuracy: 0.6600 - loss: 0.6255 - val_accuracy: 0.4497 - val_loss: 0.8575 - learning_rate: 5.0000e-04
# Epoch 11/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.6962 - loss: 0.5910
# Epoch 11: val_loss did not improve from 0.69463
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.7014 - loss: 0.5845 - val_accuracy: 0.4663 - val_loss: 1.4857 - learning_rate: 2.5000e-04
# Epoch 12/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7145 - loss: 0.5633
# Epoch 12: val_loss did not improve from 0.69463
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - accuracy: 0.7207 - loss: 0.5570 - val_accuracy: 0.4545 - val_loss: 1.7990 - learning_rate: 2.5000e-04
# Epoch 13/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.7431 - loss: 0.5219
# Epoch 13: val_loss did not improve from 0.69463
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 188ms/step - accuracy: 0.7477 - loss: 0.5227 - val_accuracy: 0.4526 - val_loss: 2.1653 - learning_rate: 2.5000e-04
# Epoch 14/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7384 - loss: 0.5319
# Epoch 14: val_loss did not improve from 0.69463
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 184ms/step - accuracy: 0.7500 - loss: 0.5154 - val_accuracy: 0.4516 - val_loss: 1.4766 - learning_rate: 2.5000e-04
# Epoch 15/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7789 - loss: 0.4832
# Epoch 15: val_loss did not improve from 0.69463
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - accuracy: 0.7702 - loss: 0.4853 - val_accuracy: 0.4585 - val_loss: 1.5782 - learning_rate: 2.5000e-04
# Epoch 16/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7858 - loss: 0.4715
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 16: val_loss did not improve from 0.69463
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 187ms/step - accuracy: 0.7898 - loss: 0.4681 - val_accuracy: 0.4575 - val_loss: 1.8608 - learning_rate: 2.5000e-04
# Epoch 17/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.7932 - loss: 0.4442
# Epoch 17: val_loss did not improve from 0.69463
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 19s 201ms/step - accuracy: 0.8031 - loss: 0.4279 - val_accuracy: 0.4545 - val_loss: 2.1123 - learning_rate: 1.2500e-04
# Epoch 18/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8226 - loss: 0.4091
# Epoch 18: val_loss did not improve from 0.69463
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 19s 196ms/step - accuracy: 0.8259 - loss: 0.4000 - val_accuracy: 0.4545 - val_loss: 1.5732 - learning_rate: 1.2500e-04
# Epoch 19/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8200 - loss: 0.3922
# Epoch 19: val_loss did not improve from 0.69463
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - accuracy: 0.8299 - loss: 0.3805 - val_accuracy: 0.4731 - val_loss: 1.3013 - learning_rate: 1.2500e-04
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 4.
# ================================================================================
# Training variant: V3_OHLC_MA_VOL
# Epoch 1/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.5185 - loss: 0.6905
# Epoch 1: val_loss improved from None to 0.87777, saving model to /Users/daijinyang/Desktop/HS300/best_V3_OHLC_MA_VOL_stronger.keras
#
# Epoch 1: finished saving model to /Users/daijinyang/Desktop/HS300/best_V3_OHLC_MA_VOL_stronger.keras
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - accuracy: 0.5381 - loss: 0.6887 - val_accuracy: 0.5474 - val_loss: 0.8778 - learning_rate: 5.0000e-04
# Epoch 2/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.5503 - loss: 0.6804
# Epoch 2: val_loss did not improve from 0.87777
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 183ms/step - accuracy: 0.5502 - loss: 0.6831 - val_accuracy: 0.5474 - val_loss: 1.0501 - learning_rate: 5.0000e-04
# Epoch 3/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.5601 - loss: 0.6758
# Epoch 3: val_loss did not improve from 0.87777
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - accuracy: 0.5629 - loss: 0.6788 - val_accuracy: 0.5474 - val_loss: 0.8966 - learning_rate: 5.0000e-04
# Epoch 4/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.5844 - loss: 0.6722
# Epoch 4: val_loss did not improve from 0.87777
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 184ms/step - accuracy: 0.5834 - loss: 0.6748 - val_accuracy: 0.5474 - val_loss: 1.0641 - learning_rate: 5.0000e-04
# Epoch 5/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.5891 - loss: 0.6660
# Epoch 5: val_loss did not improve from 0.87777
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 180ms/step - accuracy: 0.5906 - loss: 0.6677 - val_accuracy: 0.5474 - val_loss: 1.1029 - learning_rate: 5.0000e-04
# Epoch 6/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.6055 - loss: 0.6603
# Epoch 6: val_loss improved from 0.87777 to 0.87150, saving model to /Users/daijinyang/Desktop/HS300/best_V3_OHLC_MA_VOL_stronger.keras
#
# Epoch 6: finished saving model to /Users/daijinyang/Desktop/HS300/best_V3_OHLC_MA_VOL_stronger.keras
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - accuracy: 0.6063 - loss: 0.6612 - val_accuracy: 0.5474 - val_loss: 0.8715 - learning_rate: 5.0000e-04
# Epoch 7/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6143 - loss: 0.6530
# Epoch 7: val_loss improved from 0.87150 to 0.76463, saving model to /Users/daijinyang/Desktop/HS300/best_V3_OHLC_MA_VOL_stronger.keras
#
# Epoch 7: finished saving model to /Users/daijinyang/Desktop/HS300/best_V3_OHLC_MA_VOL_stronger.keras
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 172ms/step - accuracy: 0.6147 - loss: 0.6572 - val_accuracy: 0.5171 - val_loss: 0.7646 - learning_rate: 5.0000e-04
# Epoch 8/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.6380 - loss: 0.6463
# Epoch 8: val_loss improved from 0.76463 to 0.73545, saving model to /Users/daijinyang/Desktop/HS300/best_V3_OHLC_MA_VOL_stronger.keras
#
# Epoch 8: finished saving model to /Users/daijinyang/Desktop/HS300/best_V3_OHLC_MA_VOL_stronger.keras
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 169ms/step - accuracy: 0.6336 - loss: 0.6482 - val_accuracy: 0.5054 - val_loss: 0.7354 - learning_rate: 5.0000e-04
# Epoch 9/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.6429 - loss: 0.6340
# Epoch 9: val_loss did not improve from 0.73545
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 163ms/step - accuracy: 0.6532 - loss: 0.6284 - val_accuracy: 0.4721 - val_loss: 1.0485 - learning_rate: 5.0000e-04
# Epoch 10/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.6761 - loss: 0.6141
# Epoch 10: val_loss did not improve from 0.73545
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 164ms/step - accuracy: 0.6773 - loss: 0.6151 - val_accuracy: 0.4663 - val_loss: 0.9895 - learning_rate: 5.0000e-04
# Epoch 11/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.6901 - loss: 0.5838
# Epoch 11: val_loss did not improve from 0.73545
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - accuracy: 0.6845 - loss: 0.5886 - val_accuracy: 0.4624 - val_loss: 1.3722 - learning_rate: 5.0000e-04
# Epoch 12/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7013 - loss: 0.5798
# Epoch 12: val_loss did not improve from 0.73545
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 169ms/step - accuracy: 0.7135 - loss: 0.5697 - val_accuracy: 0.4673 - val_loss: 1.1172 - learning_rate: 5.0000e-04
# Epoch 13/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7290 - loss: 0.5439
# Epoch 13: val_loss did not improve from 0.73545
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 169ms/step - accuracy: 0.7304 - loss: 0.5397 - val_accuracy: 0.4712 - val_loss: 1.1271 - learning_rate: 5.0000e-04
# Epoch 14/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.7492 - loss: 0.5184
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 14: val_loss did not improve from 0.73545
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 176ms/step - accuracy: 0.7533 - loss: 0.5162 - val_accuracy: 0.5406 - val_loss: 1.3140 - learning_rate: 5.0000e-04
# Epoch 15/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.7699 - loss: 0.4787
# Epoch 15: val_loss did not improve from 0.73545
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.7862 - loss: 0.4578 - val_accuracy: 0.4487 - val_loss: 2.0254 - learning_rate: 2.5000e-04
# Epoch 16/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7967 - loss: 0.4341
# Epoch 16: val_loss did not improve from 0.73545
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - accuracy: 0.8077 - loss: 0.4261 - val_accuracy: 0.4585 - val_loss: 1.6878 - learning_rate: 2.5000e-04
# Epoch 17/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8148 - loss: 0.4078
# Epoch 17: val_loss did not improve from 0.73545
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - accuracy: 0.8158 - loss: 0.4049 - val_accuracy: 0.4614 - val_loss: 1.4758 - learning_rate: 2.5000e-04
# Epoch 18/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8306 - loss: 0.3826
# Epoch 18: val_loss did not improve from 0.73545
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 171ms/step - accuracy: 0.8380 - loss: 0.3712 - val_accuracy: 0.5142 - val_loss: 1.4068 - learning_rate: 2.5000e-04
# Epoch 19/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8386 - loss: 0.3526
# Epoch 19: val_loss did not improve from 0.73545
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - accuracy: 0.8533 - loss: 0.3394 - val_accuracy: 0.4848 - val_loss: 1.3937 - learning_rate: 2.5000e-04
# Epoch 20/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8519 - loss: 0.3445
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 20: val_loss did not improve from 0.73545
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 172ms/step - accuracy: 0.8550 - loss: 0.3381 - val_accuracy: 0.4976 - val_loss: 1.3292 - learning_rate: 2.5000e-04
# Epoch 21/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8570 - loss: 0.3195
# Epoch 21: val_loss did not improve from 0.73545
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - accuracy: 0.8745 - loss: 0.3011 - val_accuracy: 0.5132 - val_loss: 1.5843 - learning_rate: 1.2500e-04
# Epoch 22/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8882 - loss: 0.2793
# Epoch 22: val_loss did not improve from 0.73545
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 176ms/step - accuracy: 0.8928 - loss: 0.2679 - val_accuracy: 0.5347 - val_loss: 1.8547 - learning_rate: 1.2500e-04
# Epoch 23/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8956 - loss: 0.2635
# Epoch 23: val_loss did not improve from 0.73545
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - accuracy: 0.8983 - loss: 0.2576 - val_accuracy: 0.4829 - val_loss: 1.5831 - learning_rate: 1.2500e-04
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 8.
# ================================================================================
# Training variant: V4_CANDLE_MA_VOL
# Epoch 1/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.5465 - loss: 0.6898
# Epoch 1: val_loss improved from None to 0.71177, saving model to /Users/daijinyang/Desktop/HS300/best_V4_CANDLE_MA_VOL_stronger.keras
#
# Epoch 1: finished saving model to /Users/daijinyang/Desktop/HS300/best_V4_CANDLE_MA_VOL_stronger.keras
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 175ms/step - accuracy: 0.5479 - loss: 0.6874 - val_accuracy: 0.4526 - val_loss: 0.7118 - learning_rate: 5.0000e-04
# Epoch 2/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.5679 - loss: 0.6771
# Epoch 2: val_loss did not improve from 0.71177
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - accuracy: 0.5694 - loss: 0.6803 - val_accuracy: 0.4526 - val_loss: 0.7618 - learning_rate: 5.0000e-04
# Epoch 3/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.5785 - loss: 0.6752
# Epoch 3: val_loss did not improve from 0.71177
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 176ms/step - accuracy: 0.5831 - loss: 0.6768 - val_accuracy: 0.4526 - val_loss: 0.8230 - learning_rate: 5.0000e-04
# Epoch 4/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5741 - loss: 0.6739
# Epoch 4: val_loss did not improve from 0.71177
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - accuracy: 0.5857 - loss: 0.6724 - val_accuracy: 0.4526 - val_loss: 1.0641 - learning_rate: 5.0000e-04
# Epoch 5/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.5971 - loss: 0.6684
# Epoch 5: val_loss did not improve from 0.71177
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 167ms/step - accuracy: 0.6010 - loss: 0.6678 - val_accuracy: 0.4526 - val_loss: 1.0890 - learning_rate: 5.0000e-04
# Epoch 6/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.6249 - loss: 0.6556
# Epoch 6: val_loss did not improve from 0.71177
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 174ms/step - accuracy: 0.6147 - loss: 0.6585 - val_accuracy: 0.4526 - val_loss: 1.7164 - learning_rate: 5.0000e-04
# Epoch 7/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.6329 - loss: 0.6507
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 7: val_loss did not improve from 0.71177
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 173ms/step - accuracy: 0.6248 - loss: 0.6538 - val_accuracy: 0.4526 - val_loss: 0.9534 - learning_rate: 5.0000e-04
# Epoch 8/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.6597 - loss: 0.6239
# Epoch 8: val_loss did not improve from 0.71177
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 166ms/step - accuracy: 0.6594 - loss: 0.6237 - val_accuracy: 0.4526 - val_loss: 2.1813 - learning_rate: 2.5000e-04
# Epoch 9/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.6865 - loss: 0.5994
# Epoch 9: val_loss did not improve from 0.71177
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 174ms/step - accuracy: 0.6887 - loss: 0.5960 - val_accuracy: 0.4526 - val_loss: 1.9082 - learning_rate: 2.5000e-04
# Epoch 10/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.6938 - loss: 0.5835
# Epoch 10: val_loss did not improve from 0.71177
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - accuracy: 0.6949 - loss: 0.5826 - val_accuracy: 0.4516 - val_loss: 1.9182 - learning_rate: 2.5000e-04
# Epoch 11/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.7005 - loss: 0.5623
# Epoch 11: val_loss did not improve from 0.71177
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 171ms/step - accuracy: 0.7086 - loss: 0.5611 - val_accuracy: 0.4526 - val_loss: 2.3627 - learning_rate: 2.5000e-04
# Epoch 12/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.7170 - loss: 0.5506
# Epoch 12: val_loss did not improve from 0.71177
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 172ms/step - accuracy: 0.7331 - loss: 0.5428 - val_accuracy: 0.4526 - val_loss: 2.4211 - learning_rate: 2.5000e-04
# Epoch 13/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.7330 - loss: 0.5280
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 13: val_loss did not improve from 0.71177
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - accuracy: 0.7487 - loss: 0.5180 - val_accuracy: 0.4643 - val_loss: 1.3227 - learning_rate: 2.5000e-04
# Epoch 14/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.7614 - loss: 0.4913
# Epoch 14: val_loss did not improve from 0.71177
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 172ms/step - accuracy: 0.7767 - loss: 0.4795 - val_accuracy: 0.4536 - val_loss: 2.5496 - learning_rate: 1.2500e-04
# Epoch 15/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.7867 - loss: 0.4750
# Epoch 15: val_loss did not improve from 0.71177
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 172ms/step - accuracy: 0.7901 - loss: 0.4626 - val_accuracy: 0.4526 - val_loss: 2.6310 - learning_rate: 1.2500e-04
# Epoch 16/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.7820 - loss: 0.4522
# Epoch 16: val_loss did not improve from 0.71177
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 173ms/step - accuracy: 0.7885 - loss: 0.4524 - val_accuracy: 0.4536 - val_loss: 3.2469 - learning_rate: 1.2500e-04
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 1.
# ================================================================================
# Training variant: V5_HIGHRES_OHLC_MA_VOL
# Epoch 1/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.5275 - loss: 0.6880
# Epoch 1: val_loss improved from None to 0.88692, saving model to /Users/daijinyang/Desktop/HS300/best_V5_HIGHRES_OHLC_MA_VOL_stronger.keras
#
# Epoch 1: finished saving model to /Users/daijinyang/Desktop/HS300/best_V5_HIGHRES_OHLC_MA_VOL_stronger.keras
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 26s 252ms/step - accuracy: 0.5362 - loss: 0.6875 - val_accuracy: 0.5474 - val_loss: 0.8869 - learning_rate: 5.0000e-04
# Epoch 2/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.5538 - loss: 0.6753
# Epoch 2: val_loss did not improve from 0.88692
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 250ms/step - accuracy: 0.5505 - loss: 0.6814 - val_accuracy: 0.5474 - val_loss: 0.9047 - learning_rate: 5.0000e-04
# Epoch 3/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.5678 - loss: 0.6746
# Epoch 3: val_loss did not improve from 0.88692
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 253ms/step - accuracy: 0.5583 - loss: 0.6801 - val_accuracy: 0.5474 - val_loss: 1.1089 - learning_rate: 5.0000e-04
# Epoch 4/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.5676 - loss: 0.6730
# Epoch 4: val_loss improved from 0.88692 to 0.84446, saving model to /Users/daijinyang/Desktop/HS300/best_V5_HIGHRES_OHLC_MA_VOL_stronger.keras
#
# Epoch 4: finished saving model to /Users/daijinyang/Desktop/HS300/best_V5_HIGHRES_OHLC_MA_VOL_stronger.keras
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 247ms/step - accuracy: 0.5662 - loss: 0.6779 - val_accuracy: 0.5474 - val_loss: 0.8445 - learning_rate: 5.0000e-04
# Epoch 5/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.5661 - loss: 0.6717
# Epoch 5: val_loss did not improve from 0.84446
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 249ms/step - accuracy: 0.5746 - loss: 0.6749 - val_accuracy: 0.5474 - val_loss: 1.0478 - learning_rate: 5.0000e-04
# Epoch 6/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.5878 - loss: 0.6683
# Epoch 6: val_loss improved from 0.84446 to 0.70173, saving model to /Users/daijinyang/Desktop/HS300/best_V5_HIGHRES_OHLC_MA_VOL_stronger.keras
#
# Epoch 6: finished saving model to /Users/daijinyang/Desktop/HS300/best_V5_HIGHRES_OHLC_MA_VOL_stronger.keras
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 247ms/step - accuracy: 0.5887 - loss: 0.6693 - val_accuracy: 0.5034 - val_loss: 0.7017 - learning_rate: 5.0000e-04
# Epoch 7/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.6045 - loss: 0.6595
# Epoch 7: val_loss did not improve from 0.70173
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 247ms/step - accuracy: 0.6079 - loss: 0.6597 - val_accuracy: 0.5474 - val_loss: 1.0061 - learning_rate: 5.0000e-04
# Epoch 8/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.6194 - loss: 0.6480
# Epoch 8: val_loss did not improve from 0.70173
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 247ms/step - accuracy: 0.6203 - loss: 0.6515 - val_accuracy: 0.4712 - val_loss: 0.8199 - learning_rate: 5.0000e-04
# Epoch 9/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.6370 - loss: 0.6360
# Epoch 9: val_loss did not improve from 0.70173
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 252ms/step - accuracy: 0.6336 - loss: 0.6364 - val_accuracy: 0.5367 - val_loss: 0.9654 - learning_rate: 5.0000e-04
# Epoch 10/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.6369 - loss: 0.6379
# Epoch 10: val_loss did not improve from 0.70173
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 247ms/step - accuracy: 0.6441 - loss: 0.6330 - val_accuracy: 0.4604 - val_loss: 0.8493 - learning_rate: 5.0000e-04
# Epoch 11/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.6757 - loss: 0.6157
# Epoch 11: val_loss did not improve from 0.70173
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 248ms/step - accuracy: 0.6714 - loss: 0.6104 - val_accuracy: 0.4457 - val_loss: 0.8084 - learning_rate: 5.0000e-04
# Epoch 12/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.6928 - loss: 0.5862
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 12: val_loss did not improve from 0.70173
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 250ms/step - accuracy: 0.6868 - loss: 0.5891 - val_accuracy: 0.4604 - val_loss: 1.3109 - learning_rate: 5.0000e-04
# Epoch 13/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.7185 - loss: 0.5472
# Epoch 13: val_loss did not improve from 0.70173
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 248ms/step - accuracy: 0.7164 - loss: 0.5473 - val_accuracy: 0.4819 - val_loss: 1.0136 - learning_rate: 2.5000e-04
# Epoch 14/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.7377 - loss: 0.5367
# Epoch 14: val_loss did not improve from 0.70173
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 248ms/step - accuracy: 0.7357 - loss: 0.5292 - val_accuracy: 0.4712 - val_loss: 1.3082 - learning_rate: 2.5000e-04
# Epoch 15/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.7648 - loss: 0.4941
# Epoch 15: val_loss did not improve from 0.70173
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 25s 257ms/step - accuracy: 0.7643 - loss: 0.4940 - val_accuracy: 0.4731 - val_loss: 1.8315 - learning_rate: 2.5000e-04
# Epoch 16/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.7666 - loss: 0.4805
# Epoch 16: val_loss did not improve from 0.70173
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 253ms/step - accuracy: 0.7722 - loss: 0.4792 - val_accuracy: 0.4624 - val_loss: 1.1805 - learning_rate: 2.5000e-04
# Epoch 17/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.7998 - loss: 0.4489
# Epoch 17: val_loss did not improve from 0.70173
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 249ms/step - accuracy: 0.7963 - loss: 0.4447 - val_accuracy: 0.4516 - val_loss: 2.5799 - learning_rate: 2.5000e-04
# Epoch 18/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.7970 - loss: 0.4462
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 18: val_loss did not improve from 0.70173
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 248ms/step - accuracy: 0.7953 - loss: 0.4336 - val_accuracy: 0.4477 - val_loss: 3.0900 - learning_rate: 2.5000e-04
# Epoch 19/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8115 - loss: 0.4047
# Epoch 19: val_loss did not improve from 0.70173
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 248ms/step - accuracy: 0.8198 - loss: 0.3982 - val_accuracy: 0.4575 - val_loss: 2.3331 - learning_rate: 1.2500e-04
# Epoch 20/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8400 - loss: 0.3786
# Epoch 20: val_loss did not improve from 0.70173
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 247ms/step - accuracy: 0.8406 - loss: 0.3746 - val_accuracy: 0.4604 - val_loss: 2.2911 - learning_rate: 1.2500e-04
# Epoch 21/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8485 - loss: 0.3604
# Epoch 21: val_loss did not improve from 0.70173
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 24s 247ms/step - accuracy: 0.8416 - loss: 0.3596 - val_accuracy: 0.4575 - val_loss: 2.7485 - learning_rate: 1.2500e-04
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 6.
# ================================================================================
# Training variant: V6_VOL30_OHLC_MA_VOL
# Epoch 1/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.5380 - loss: 0.6888
# Epoch 1: val_loss improved from None to 0.81560, saving model to /Users/daijinyang/Desktop/HS300/best_V6_VOL30_OHLC_MA_VOL_stronger.keras
#
# Epoch 1: finished saving model to /Users/daijinyang/Desktop/HS300/best_V6_VOL30_OHLC_MA_VOL_stronger.keras
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.5495 - loss: 0.6865 - val_accuracy: 0.5474 - val_loss: 0.8156 - learning_rate: 5.0000e-04
# Epoch 2/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.5505 - loss: 0.6795
# Epoch 2: val_loss did not improve from 0.81560
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 169ms/step - accuracy: 0.5554 - loss: 0.6837 - val_accuracy: 0.5474 - val_loss: 0.9429 - learning_rate: 5.0000e-04
# Epoch 3/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.5517 - loss: 0.6753
# Epoch 3: val_loss did not improve from 0.81560
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 169ms/step - accuracy: 0.5600 - loss: 0.6779 - val_accuracy: 0.5474 - val_loss: 0.8320 - learning_rate: 5.0000e-04
# Epoch 4/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.5746 - loss: 0.6713
# Epoch 4: val_loss did not improve from 0.81560
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - accuracy: 0.5658 - loss: 0.6756 - val_accuracy: 0.5474 - val_loss: 1.5462 - learning_rate: 5.0000e-04
# Epoch 5/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.5962 - loss: 0.6665
# Epoch 5: val_loss did not improve from 0.81560
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 171ms/step - accuracy: 0.5913 - loss: 0.6694 - val_accuracy: 0.5474 - val_loss: 1.1610 - learning_rate: 5.0000e-04
# Epoch 6/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.5972 - loss: 0.6670
# Epoch 6: val_loss did not improve from 0.81560
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - accuracy: 0.6072 - loss: 0.6639 - val_accuracy: 0.5474 - val_loss: 1.2972 - learning_rate: 5.0000e-04
# Epoch 7/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6084 - loss: 0.6572
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 7: val_loss did not improve from 0.81560
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 171ms/step - accuracy: 0.6203 - loss: 0.6543 - val_accuracy: 0.5474 - val_loss: 1.0543 - learning_rate: 5.0000e-04
# Epoch 8/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.6417 - loss: 0.6349
# Epoch 8: val_loss did not improve from 0.81560
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 172ms/step - accuracy: 0.6519 - loss: 0.6261 - val_accuracy: 0.5474 - val_loss: 1.3273 - learning_rate: 2.5000e-04
# Epoch 9/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.6532 - loss: 0.6206
# Epoch 9: val_loss did not improve from 0.81560
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 172ms/step - accuracy: 0.6701 - loss: 0.6048 - val_accuracy: 0.5474 - val_loss: 1.8310 - learning_rate: 2.5000e-04
# Epoch 10/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6839 - loss: 0.5925
# Epoch 10: val_loss did not improve from 0.81560
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 171ms/step - accuracy: 0.6900 - loss: 0.5867 - val_accuracy: 0.5474 - val_loss: 1.4037 - learning_rate: 2.5000e-04
# Epoch 11/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.6962 - loss: 0.5673
# Epoch 11: val_loss did not improve from 0.81560
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - accuracy: 0.7106 - loss: 0.5660 - val_accuracy: 0.5445 - val_loss: 0.9845 - learning_rate: 2.5000e-04
# Epoch 12/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7349 - loss: 0.5499
# Epoch 12: val_loss did not improve from 0.81560
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - accuracy: 0.7324 - loss: 0.5436 - val_accuracy: 0.5474 - val_loss: 2.3307 - learning_rate: 2.5000e-04
# Epoch 13/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7438 - loss: 0.5145
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 13: val_loss did not improve from 0.81560
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - accuracy: 0.7441 - loss: 0.5198 - val_accuracy: 0.5562 - val_loss: 1.4689 - learning_rate: 2.5000e-04
# Epoch 14/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7609 - loss: 0.4965
# Epoch 14: val_loss did not improve from 0.81560
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 171ms/step - accuracy: 0.7669 - loss: 0.4835 - val_accuracy: 0.5474 - val_loss: 2.2068 - learning_rate: 1.2500e-04
# Epoch 15/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7982 - loss: 0.4454
# Epoch 15: val_loss did not improve from 0.81560
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - accuracy: 0.8008 - loss: 0.4417 - val_accuracy: 0.5474 - val_loss: 2.5127 - learning_rate: 1.2500e-04
# Epoch 16/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7898 - loss: 0.4464
# Epoch 16: val_loss did not improve from 0.81560
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 171ms/step - accuracy: 0.8041 - loss: 0.4355 - val_accuracy: 0.5494 - val_loss: 1.5938 - learning_rate: 1.2500e-04
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 1.
#                   Variant  Validation Accuracy  Test Accuracy  Annual Return  \
# 0              V2_OHLC_MA             0.484848       0.518084       0.047085
# 1          V3_OHLC_MA_VOL             0.505376       0.535679       0.045248
# 2  V5_HIGHRES_OHLC_MA_VOL             0.503421       0.514174       0.019742
# 3                 V1_OHLC             0.547410       0.477028      -0.019109
# 4    V6_VOL30_OHLC_MA_VOL             0.547410       0.477028      -0.019109
# 5        V4_CANDLE_MA_VOL             0.452590       0.522972       0.000000
#
#    Annual Vol    Sharpe  Max Drawdown  Average Exposure
# 0    0.141920  0.331772     -0.163974          0.666991
# 1    0.158500  0.285476     -0.259048          0.817916
# 2    0.157130  0.125641     -0.249235          0.813048
# 3    0.175182 -0.109082     -0.360525          0.998053
# 4    0.175182 -0.109082     -0.360525          0.998053
# 5    0.000000       NaN      0.000000          0.000000

# %% [markdown]
# ## Plot timing strategy vs HS300 for each rendering variant

# %%
# ============================================================
# 11. Individual plots
# ============================================================
for v in variants:
    print("\n", "#" * 30, v, "#" * 30)
    plot_strategy_vs_hs300_visible(backtests[v], v)
# Out:
#  ############################## V1_OHLC ##############################
#  ############################## V2_OHLC_MA ##############################
#  ############################## V3_OHLC_MA_VOL ##############################
#  ############################## V4_CANDLE_MA_VOL ##############################
#  ############################## V5_HIGHRES_OHLC_MA_VOL ##############################
#  ############################## V6_VOL30_OHLC_MA_VOL ##############################

# %% [markdown]
# ## Compare all rendering variants on one chart

# %%
# ============================================================
# 12. All variants vs HS300 on one chart
# ============================================================
plt.figure(figsize=(14, 7))
base = backtests[variants[0]]
plt.plot(base["date"], base["buy_hold_nav"], label="HS300 Buy-and-Hold", linewidth=3)

for v in variants:
    plt.plot(backtests[v]["date"], backtests[v]["strategy_nav"], label=v, linewidth=1.5)

plt.title("Image Rendering Sensitivity: All Variants vs HS300 (5-Day Silent Holding Rule)")
plt.xlabel("Date")
plt.ylabel("Net Asset Value")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Interpretation of this notebook
#
# The purpose of this notebook is to test whether prediction performance changes when the **image rendering rule** changes, while everything else stays fixed:
#
# - the same 20-day input window,
# - the same future 5-day classification target,
# - the same train / validation / test split,
# - the same 2D CNN architecture,
# - the same Scheme A backtest with a 5-day silent holding rule.
#
# Therefore, any performance differences here should mainly come from the **image representation itself**, not from a different model or a different label definition.
